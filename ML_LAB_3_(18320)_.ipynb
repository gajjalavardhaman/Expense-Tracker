# %% [markdown]
# <a href="https://colab.research.google.com/github/gajjalavardhaman/Expense-Tracker/blob/main/ML_LAB_3_(18320)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: G vardhaman
#
# Rollno: AM.EN.U4CSE18320
#
# Link:https://colab.research.google.com/drive/1DZExGdzwgIS__lgR512h1rry2eh7RE2q?usp=sharing

# %%
import pandas as pd
from pandas import read_csv
path='diabetes_dataset.csv'
data = read_csv(path)
arr = data.values
X=arr[:,0:8]
Y=arr[:,8]
k=[1,3,5,7,9,11,13,15]

# %%
#partitioning k-fold cross validation
from sklearn.model_selection import RepeatedKFold
kf = RepeatedKFold(n_splits=5, n_repeats=10, random_state=None) 
for train_index,test_index in kf.split(X):
    X_train,X_test = X[train_index],X[test_index]
    Y_train,Y_test = Y[train_index],Y[test_index]
from sklearn.preprocessing import StandardScaler
scaler1=StandardScaler().fit(X_train)
scaler2=StandardScaler().fit(X_test)
X_train = scaler1.transform(X_train)
X_test = scaler2.transform(X_test)

# %%
for i in k:
    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors=i)
    classifier.fit(X_train,Y_train)
    Y_pred = classifier.predict_proba(X_test)
    from sklearn.metrics import roc_curve
    fpr,tpr ,threshold = roc_curve(Y_test,Y_pred[:,1])
    from sklearn.metrics import roc_auc_score
    roc_auc = roc_auc_score(Y_test, Y_pred [:, 1])
    print('partiotining roc_auc for k=',i,'is',roc_auc)
    import matplotlib.pyplot as plt
    plt.style.use('seaborn')
    plt.legend(loc = 'lower right')  #Set Legend at lower rights
    plt.plot([0, 1], [0, 1],'r--') #Set baseline model as diagonal
    plt.xlim([0, 1]) # Set x axis limits
    plt.ylim([0, 1]) # Set y axis limits
    plt.ylabel('True Positive Rate') # y label
    plt.xlabel('False Positive Rate') # x label
    plt.plot(fpr, tpr, linestyle='--', label = 'AUC = %0.2f' %roc_auc) # plot roc curves
    plt.title('partitioning k-fold cross validation')
    plt.show();
# Out:
# No handles with labels found to put in legend.
# partiotining roc_auc for k= 1 is 0.6658415841584159
# partiotining roc_auc for k= 3 is 0.7023990860624524
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# partiotining roc_auc for k= 5 is 0.7353389185072354
# No handles with labels found to put in legend.
# partiotining roc_auc for k= 7 is 0.7641850723533892
# partiotining roc_auc for k= 9 is 0.7898895658796649
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# partiotining roc_auc for k= 11 is 0.7744668697638994
# No handles with labels found to put in legend.
# partiotining roc_auc for k= 13 is 0.7738004569687738
# partiotining roc_auc for k= 15 is 0.7835110434120335
# No handles with labels found to put in legend.

# %%
#stratified k-fold cross validation
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits = 5,random_state=None)
for train_index,test_index in kf.split(X):
    X_train,X_test = X[train_index],X[test_index]
    Y_train,Y_test = Y[train_index],Y[test_index]
from sklearn.preprocessing import StandardScaler
scaler1=StandardScaler().fit(X_train)
scaler2=StandardScaler().fit(X_test)
X_train = scaler1.transform(X_train)
X_test = scaler2.transform(X_test)

# %%
for i in k:
    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors=i)
    classifier.fit(X_train,Y_train)
    Y_pred = classifier.predict_proba(X_test)
    from sklearn.metrics import roc_curve
    fpr,tpr ,threshold = roc_curve(Y_test,Y_pred[:,1])
    from sklearn.metrics import roc_auc_score
    roc_auc = roc_auc_score(Y_test, Y_pred [:, 1])
    print('stratified roc_auc for k=',i,'is',roc_auc)
    import matplotlib.pyplot as plt
    plt.style.use('seaborn')
    plt.legend(loc = 'lower right')  #Set Legend at lower rights
    plt.plot([0, 1], [0, 1],'r--') #Set baseline model as diagonal
    plt.xlim([0, 1]) # Set x axis limits
    plt.ylim([0, 1]) # Set y axis limits
    plt.ylabel('True Positive Rate') # y label
    plt.xlabel('False Positive Rate') # x label
    plt.plot(fpr, tpr, linestyle='--', label = 'AUC = %0.2f' %roc_auc) # plot roc curves
    plt.title('startified k-fold cross validation')
    plt.show();
# Out:
# No handles with labels found to put in legend.
# stratified roc_auc for k= 1 is 0.6918867924528301
# No handles with labels found to put in legend.
# stratified roc_auc for k= 3 is 0.7681132075471698
# No handles with labels found to put in legend.
# stratified roc_auc for k= 5 is 0.8056603773584906
# No handles with labels found to put in legend.
# stratified roc_auc for k= 7 is 0.8057547169811321
# No handles with labels found to put in legend.
# stratified roc_auc for k= 9 is 0.8132075471698113
# No handles with labels found to put in legend.
# stratified roc_auc for k= 11 is 0.8254716981132075
# No handles with labels found to put in legend.
# stratified roc_auc for k= 13 is 0.8234905660377358
# No handles with labels found to put in legend.
# stratified roc_auc for k= 15 is 0.8257547169811321

# %%
#simple k-fold cross validation with repetetion
from sklearn.model_selection import RepeatedKFold
rkf = RepeatedKFold(n_splits=5,n_repeats = 10,random_state = None)
for train_index,test_index in rkf.split(X):
    X_train,X_test = X[train_index],X[test_index]
    Y_train,Y_test = Y[train_index],Y[test_index]
from sklearn.preprocessing import StandardScaler
scaler1=StandardScaler().fit(X_train)
scaler2=StandardScaler().fit(X_test)
X_train = scaler1.transform(X_train)
X_test = scaler2.transform(X_test)

# %%
for i in k:
    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors=i)
    classifier.fit(X_train,Y_train)
    Y_pred = classifier.predict_proba(X_test)
    from sklearn.metrics import roc_curve
    fpr,tpr ,threshold = roc_curve(Y_test,Y_pred[:,1])
    from sklearn.metrics import roc_auc_score
    roc_auc = roc_auc_score(Y_test, Y_pred [:, 1])
    print('roc_auc for k=',i,'is',roc_auc)
    import matplotlib.pyplot as plt
    plt.style.use('seaborn')
    plt.legend(loc = 'lower right')  #Set Legend at lower rights
    plt.plot([0, 1], [0, 1],'r--') #Set baseline model as diagonal
    plt.xlim([0, 1]) # Set x axis limits
    plt.ylim([0, 1]) # Set y axis limits
    plt.ylabel('True Positive Rate') # y label
    plt.xlabel('False Positive Rate') # x label
    plt.plot(fpr, tpr, linestyle='--', label = 'AUC = %0.2f' %roc_auc) # plot roc curves
    plt.title('simple k-fold cross validation with repetetion')
    plt.show();
# Out:
# No handles with labels found to put in legend.
# roc_auc for k= 1 is 0.6785971871619184
# No handles with labels found to put in legend.
# roc_auc for k= 3 is 0.7479264334655609
# roc_auc for k= 5 is 0.7665885322755139
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# roc_auc for k= 7 is 0.7754237288135593
# No handles with labels found to put in legend.
# roc_auc for k= 9 is 0.7754237288135593
# No handles with labels found to put in legend.
# roc_auc for k= 11 is 0.7759646592138479
# No handles with labels found to put in legend.
# roc_auc for k= 13 is 0.779120086548864
# No handles with labels found to put in legend.
# roc_auc for k= 15 is 0.7893076090876308

# %% [markdown]
# B)for different times of execution the results are being different but for majority of cases simple k-fold cross validation with repetetion has shown the better score than the other two models.
